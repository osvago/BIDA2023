# %% [markdown]
# <a href="https://colab.research.google.com/github/osvago/BIDA2023/blob/main/CalcRev.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Review of Calculus tools: Functions in one variable $f(x)$

# %%
# importing the required modules
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# Visualization of basic functions and its derivatives

# %%
# setting the x - coordinates
x = np.arange(-2, 2, 0.1)
# setting the corresponding y - coordinates
y = np.square(x)
  
# plotting the points
plt.plot(x, y)
  
# function to show the plot
plt.show()

# %% [markdown]
# Define the Sigmoid Function

# %%
# setting the x - coordinates
x = np.arange(-5, 5, 0.1)
# setting the corresponding y - coordinates
def sigmoid(x):
  return 1/(1+np.exp(-x))


y = sigmoid(x)
  
# plotting the points
plt.plot(x, y)
  
# function to show the plot
plt.show()

# %% [markdown]
# Find the derivative and plot its graph

# %%
D = np.gradient(y)
plt.plot(x,D)
plt.show()

# %% [markdown]
# Visialization of 2D functions

# %%
# Import libraries
from mpl_toolkits import mplot3d
 
# Creating dataset
x = np.outer(np.linspace(-5, 5, 200), np.ones(200))
y = x.copy().T # transpose
z = (np.square(x)+3*np.square(y))*np.exp(-1-np.square(x)-np.square(y))
 
# Creating figure
fig = plt.figure(figsize =(14, 9))
ax = plt.axes(projection ='3d')
 
# Creating plot
ax.plot_surface(x, y, z)
 
# show plot
plt.show()

# %%
#Create Contour lines
plt.contour(x,y,z)
plt.show()
